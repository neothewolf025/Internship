# %%
import pandas as pd
from bs4 import BeautifulSoup
import selenium
import time
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException
import sys
from selenium.common import exceptions
import io
from selenium.webdriver.chrome.options import Options
import requests
import re

# %% [markdown]
# # Q1.

# %%
driver= webdriver.Chrome("chromedriver")

# %%
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
Name=[]
Rank=[]
Artist=[]
Upload_date=[]
Views=[]

try:
        rank=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]//tbody//tr//td[1]")
        for i in rank:
            Rank.append(i.text)
except NoSuchElementException:
        Rank.append('-')
except StaleElementReferenceException:
        Rank.append('-')
        
        
try:
        name=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]//tbody//tr//td[2]")
        for i in name:
            Name.append(i.text)
except NoSuchElementException:
        Name.append('-')
except StaleElementReferenceException:
        Name.append('-')
time.sleep(2)

try:
        artist=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]//tbody//tr//td[3]")
        for i in artist:
            Artist.append(i.text)
except NoSuchElementException:
        Artist.append('-')
except StaleElementReferenceException:
        Artist.append('-')
        
try:
        upload_date=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]//tbody//tr//td[5]")
        for i in upload_date:
            Upload_date.append(i.text)
except NoSuchElementException:
        Upload_date.append('-')
except StaleElementReferenceException:
        Upload_date.append('-')
        
try:
        views=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]//tbody//tr//td[4]")
        for i in views:
            Views.append(i.text)
except NoSuchElementException:
        Views.append('-')
except StaleElementReferenceException:
        Views.append('-')

# %%
most_watched=pd.DataFrame({})
most_watched['Rank']=Rank
most_watched['Name']=Name
most_watched['Artist']=Artist
most_watched['Views(in billions)']=Views
most_watched['Upload_date']=Upload_date
most_watched
# Out:
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[23]
# 1    2.                                  "Despacito"[25]
# 2    3.                       "Johny Johny Yes Papa"[26]
# 3    4.                               "Shape of You"[27]
# 4    5.                              "See You Again"[28]
# 5    6.                                  "Bath Song"[31]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[32]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[33]
# 8    9.                                "Uptown Funk"[34]
# 9   10.                "Phonics Song with Two Words"[35]
# 10  11.                              "Gangnam Style"[36]
# 11  12.                             "Dame Tu Cosita"[38]
# 12  13.                                      "Sugar"[39]
# 13  14.                                      "Sorry"[40]
# 14  15.                                       "Roar"[41]
# ...

# %% [markdown]
# # Q2.

# %%
driver= webdriver.Chrome("chromedriver")

# %%
url='https://www.bcci.tv/'
driver.get(url)

# %%
menu_button=driver.find_element_by_xpath("//button[@class='navigation__header-button menu-button js-navigation-menu-button']")
menu_button
menu_button.click()

# %%
int_fixtures=driver.find_element_by_xpath("//ul[@class='navigation__list showMoreEnabled']//li[@data-nav-index='0'][1]//div[2]//div//ul//li[1]//a")
int_fixtures
try:
    int_fixtures.click()
    
except ElementNotInteractableException:
    driver.get(int_fixtures.get_attribute('href'))

# %%
showmore_button=driver.find_element_by_xpath("//button[@class='load-more-button u-center js-show-more-button js-loader']")
showmore_button
showmore_button.click()

# %%
urls=[]
match_page=driver.find_elements_by_xpath("//div[@class='js-list']//a")
for i in match_page:
    urls.append(i.get_attribute('href'))

# %%
Match=[]
Series=[]
Place=[]
Date=[]
Time=[]
for i in urls:
    driver.get(i)
    try:
        match=driver.find_element_by_xpath("//p[@class='mc-header-info__match-description']//span")
        Match.append(match.text)
    except NoSuchElementException:
        Match.append('-')
    
    try:
        series=driver.find_element_by_xpath("//section[@class='widget widget--with-footer widget--small match-info match-info--main js-prematch-info mc-theme-pseudo']//div[1]//ul[1]//li[1]//span[2]")
        Series.append(series.text)
    except NoSuchElementException:
        Series.append('-')
        
    try:
        place=driver.find_element_by_xpath("//section[@class='widget widget--with-footer widget--small match-info match-info--main js-prematch-info mc-theme-pseudo']//div[1]//ul[1]//li[3]//span[2]")
        Place.append(place.text)
    except NoSuchElementException:
        Place.append('-')
        
    try:
        date=driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']//strong")
        Date.append(date.text)
    except NoSuchElementException:
        Date.append('-')
        
    try:
        time=driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']//span[1]")
        Time.append(time.text)
    except NoSuchElementException:
        Time.append('-')

# %%
len(Series)
# Out:
# 20

# %%
fixtures=pd.DataFrame({})
fixtures['Matches']=Match
fixtures['Series']=Series
fixtures['Place']=Place
fixtures['Date']=Date
fixtures['Time']=Time
fixtures
# Out:
#      Matches                          Series  \
# 0   MATCH 16    2021 ICC Men's T20 World Cup
# 1   MATCH 28    2021 ICC Men's T20 World Cup
# 2   MATCH 33    2021 ICC Men's T20 World Cup
# 3   MATCH 37    2021 ICC Men's T20 World Cup
# 4   MATCH 42    2021 ICC Men's T20 World Cup
# 5   1ST T20I        India v New Zealand 2021
# 6   2ND T20I        India v New Zealand 2021
# 7   3RD T20I        India v New Zealand 2021
# 8   1ST TEST        India v New Zealand 2021
# 9   2ND TEST        India v New Zealand 2021
# 10  1ST TEST  South Africa v India 2021/2022
# 11  2ND TEST  South Africa v India 2021/2022
# 12  3RD TEST  South Africa v India 2021/2022
# 13   1ST ODI  South Africa v India 2021/2022
# 14   2ND ODI  South Africa v India 2021/2022
# 15   3RD ODI  South Africa v India 2021/2022
# 16  1ST T20I  South Africa v India 2021/2022
# 17  2ND T20I  South Africa v India 2021/2022
# 18  3RD T20I  South Africa v India 2021/2022
# 19  4TH T20I  South Africa v India 2021/2022
# ...

# %% [markdown]
# # Q3.

# %%
driver= webdriver.Chrome("chromedriver")

# %%
url='https://www.guru99.com/'
driver.get(url)

# %%
button_1=driver.find_element_by_xpath("//div[@class='col-md-3'][1]//ul[@class='menu1' and @id='java_technologies'][1]//li[3]//a")
button_1
button_1.click()

# %%
button_2=driver.find_element_by_xpath("//div[@class='entry-content single-content']//table[5]//tr[34]//td[1]//a")
button_2
button_2.click()

# %%
Data=[]
Name=[]
Description=[]

table=driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td")
for i in table:
    try:
        Data.append(i.text)
    except NoSuchElementException:
        Data.append('-')

for i in range(0,len(Data),2):
    Name.append(Data[i])
for i in range(1,len(Data),2):
    Description.append(Data[i])

# %%
len(Name)
# Out:
# 41

# %%
exception=pd.DataFrame({})
exception['Name']=Name
exception['Description']=Description
exception
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# # Q4.

# %%
url = "http://statisticstimes.com/"
driver.get(url)

# %%
economy_button=driver.find_element_by_xpath("//div[@class='navbar']//div[2]//div//a[3]")
try:
    economy_button.click()
except ElementNotInteractableException:
    driver.get(economy_button.get_attribute('href'))

# %%
gdp_button=driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']//li[1]//a[1]")
try:
    gdp_button.click()
except ElementNotInteractableException:
    driver.get(gdp_button.get_attribute('href'))

# %%
Rank=[]
State=[]
GSDP1=[]
GSDP2=[]
Share=[]
GDP=[]
try:
    rank=driver.find_elements_by_xpath("//table[@id='table_id']//tbody//tr//td[1]")
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')
    

try:
    state=driver.find_elements_by_xpath("//table[@id='table_id']//tbody//tr//td[2]")
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('-')

try:
    gsdp1=driver.find_elements_by_xpath("//table[@id='table_id']//tbody//tr//td[3]")
    for i in gsdp1:
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append('-')
    
try:
    gsdp2=driver.find_elements_by_xpath("//table[@id='table_id']//tbody//tr//td[4]")
    for i in gsdp2:
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append('-')
    
try:
    share=driver.find_elements_by_xpath("//table[@id='table_id']//tbody//tr//td[5]")
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('-')
    
try:
    gdp=driver.find_elements_by_xpath("//table[@id='table_id']//tbody//tr//td[6]")
    for i in gdp:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('-')

# %%
statistic=pd.DataFrame({})
statistic['Rank']=Rank
statistic['State']=State
statistic['GSDP19/20']=GSDP1
statistic['GSDP18/19']=GSDP2
statistic['Share']=Share
statistic['GDP']=GDP
statistic
# Out:
#    Rank                      State  GSDP19/20  GSDP18/19   Share      GDP
# 0     1                Maharashtra          -  2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%  240.726
# 3     4                    Gujarat          -  1,502,899   7.96%  228.290
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%  226.806
# 5     6                West Bengal  1,253,832  1,089,898   5.77%  165.556
# 6     7                  Rajasthan  1,020,989    942,586   4.99%  143.179
# 7     8             Andhra Pradesh    972,782    862,957   4.57%  131.083
# 8     9                  Telangana    969,604    861,031   4.56%  130.791
# 9    10             Madhya Pradesh    906,672    809,592   4.29%  122.977
# 10   11                     Kerala          -    781,653   4.14%  118.733
# 11   12                      Delhi    856,112    774,870   4.10%  117.703
# ...

# %% [markdown]
# # Q5.

# %%
driver= webdriver.Chrome("chromedriver")

# %%
url="https://github.com/"
driver.get(url)

# %%
menu_button=driver.find_element_by_xpath("//button[@class='js-details-target btn-link d-lg-none mt-1']")
menu_button
menu_button.click()

# %%
explore_button=driver.find_element_by_xpath("//summary[contains(text(),'Explore')]")
explore_button
explore_button.click()

# %%
trending_button=driver.find_element_by_xpath("//div[@class='dropdown-menu flex-auto rounded px-0 pt-2 pb-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4']//ul[2]//li[3]")
trending_button
trending_button.click()

# %%
URLS=[]
urls=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']//a")
for i in urls:
    URLS.append(i.get_attribute('href'))

# %%
Name=[]
try:
        name=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']//a")
        for i in name:
            Name.append(i.text)
except NoSuchElementException:
        Name.append('-')

# %%
Desc=[]
Contributors=[]



for i in URLS:
    driver.get(i)
    
        
    try:
        desc=driver.find_element_by_xpath("//p[@class='f4 mt-3']")
        Desc.append(desc.text)
    except NoSuchElementException:
        Desc.append('-')
        
    try:
        contributors=driver.find_element_by_xpath("//a[contains(text(),'Contributors')]//span")
        Contributors.append(contributors.text)
    except NoSuchElementException:
        Contributors.append('-')

# %%
for i in URLS:
    driver.get(i)
    time.sleep(3)
    languages_used=driver.find_elements_by_xpath("//h2[text()='Languages']//parent::div[@class='BorderGrid-cell']//ul//*//span[1]")
    Languages_used=[]
    Languages_used.clear()
    for j in languages_used:
        if j.text.split(' ')[0].isalpha() == True:
            Languages_used.append(j.text.split(' ')[0])
            
        else:
            Languages_used.append('-')

# %%
Languages_used
# Out:
# ['Vue', 'TypeScript', 'JavaScript', 'SCSS', '-', 'Other']

# %%
github=pd.DataFrame({})
github['Name']=Name
github['Description']=Desc
github['Contributors']=Contributors
github['Languages_used']=", ".join(Languages_used)
github
# Out:
#                                             Name  \
# 0                             NVlabs / stylegan3
# 1                                   goplus / gop
# 2                     fosscord / fosscord-server
# 3                       KieSun / all-of-frontend
# 4                               Chakazul / Lenia
# 5                           cypress-io / cypress
# 6   WebDevSimplified / useful-custom-react-hooks
# 7   practical-tutorials / project-based-learning
# 8                     marcelja / facebook-delete
# 9                            fosscord / fosscord
# 10                ZhangNanBei / WokerLifeMatters
# 11                   jackfrued / Python-100-Days
# 12                 AveYo / MediaCreationTool.bat
# 13                               ethereum / EIPs
# 14                         xinntao / Real-ESRGAN
# 15              trekhleb / javascript-algorithms
# 16                        raimohanska / ourboard
# 17                            milvus-io / milvus
# ...

# %% [markdown]
# # Q6.

# %%
Url ='https://www.billboard.com/'
driver.get(Url)

# %%
driver.set_page_load_timeout(300)

# %%
hot100=driver.find_element_by_xpath("//a[contains(text(),'Hot 100') and @class='header__subnav__link text--uppercase font--semi-bold']")
hot100
hot100.click()

# %%
Song_name=[]
Artist=[]
Lastweek_rank=[]
Peak_rank=[]
Weeks_on_chart=[]

try:
    song_name=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
    for i in song_name:
        Song_name.append(i.text)
except NoSuchElementException:
    Song_name.append('-')
    
try:
    artist=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append('-')
    
try:
    lastweek_rank=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
    for i in lastweek_rank:
        Lastweek_rank.append(i.text)
except NoSuchElementException:
    Lastweek_rank.append('-')
    
try:
    peak_rank=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
    for i in peak_rank:
        Peak_rank.append(i.text)
except NoSuchElementException:
    Peak_rank.append('-')
    
try:
    weeks_on_chart=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
    for i in weeks_on_chart:
        Weeks_on_chart.append(i.text)
except NoSuchElementException:
    Weeks_on_chart.append('-')

# %%
len(Weeks_on_chart)
# Out:
# 100

# %%
billboard=pd.DataFrame({})
billboard['Song_name']=Song_name
billboard['Artist']=Artist
billboard['Last_week_rank']=Lastweek_rank
billboard['Peak_rank']=Peak_rank
billboard['Weeks_on_chart']=Weeks_on_chart
billboard
# Out:
#         Song_name                                Artist Last_week_rank  \
# 0     My Universe                        Coldplay x BTS              -
# 1            Stay         The Kid LAROI & Justin Bieber              1
# 2   Industry Baby               Lil Nas X & Jack Harlow              2
# 3      Way 2 Sexy   Drake Featuring Future & Young Thug              3
# 4      Fancy Like                          Walker Hayes              5
# ..            ...                                   ...            ...
# 95      Pipe Down                                 Drake             68
# 96    Papi's Home                                 Drake             66
# 97         Chosen  Blxst & Tyga Featuring Ty Dolla $ign              -
# 98     Toxic Punk            YoungBoy Never Broke Again              -
# 99           Moon                            Kanye West             76
#
#    Peak_rank Weeks_on_chart
# 0          1              1
# 1          1             12
# ...

# %% [markdown]
# # Q7.

# %%
driver= webdriver.Chrome("chromedriver")

# %%
url = "https://www.naukri.com/"
driver.get(url)

# %%
recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
recruiters
driver.get(recruiters.get_attribute('href'))

# %%
search_bar=driver.find_element_by_xpath("//input[@class='sugInp']")
search_bar
search_bar.send_keys("Data Science")

# %%
search_btn= driver.find_element_by_id("qsbFormBtn")
search_btn
search_btn.click()

# %%
Name=[]
Designation=[]
Company=[]
Skills=[]
Location=[]

try:
    name=driver.find_elements_by_xpath("//p[@class='highlightable']//a//span[@class='fl ellipsis']")
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
    
try:
    designation=driver.find_elements_by_xpath("//p[@class='highlightable']//span[@class='ellipsis clr']")
    for i in designation:
        Designation.append(i.text)
except NoSuchElementException:
    Designation.append('-')
    
try:
    company=driver.find_elements_by_xpath("//p[@class='highlightable']//a[@class='ellipsis'][2]")
    for i in company:
        Company.append(i.text)
except NoSuchElementException:
    Company.append('-')
    
try:
    skills=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
    for i in skills:
        Skills.append(i.text)
except NoSuchElementException:
    Skills.append('-')
    
soup=BeautifulSoup(driver.page_source,'html.parser')
l=soup.find_all('div',attrs={'vcard'})
for i in l:
    try:
        Location.append(i.find('small').text)
    except AttributeError :
        Location.append("No details available")

# %%
naukri=pd.DataFrame({})
naukri['Name']=Name
naukri['Designation']=Designation
naukri['Company']=Company
naukri['Skills']=Skills
naukri['Location']=Location
naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                       Narasimha
# 5                                    subhas patel
# 6    Abhishek - Only Analytics Hiring - India and
# 7   Institute for Financial Management and Resear
# 8                                     Balu Ramesh
# 9                                   Asif Lucknowi
# 10                                InstaFinancials
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                                    Ruchi Dhote
# 16                             Mahesh Babu Channa
# 17                                   Kapil Devang
# ...

# %% [markdown]
# # Q8.

# %%
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)

# %%
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]
try:
    book_name=driver.find_elements_by_xpath("//tbody//td[@class='left'][2]")
    for i in book_name:
        Book_name.append(i.text)
except NoSuchElementException:
    Book_name.append('')
    
try:
    author_name=driver.find_elements_by_xpath("//tbody//td[@class='left'][3]")
    for i in author_name:
        Author_name.append(i.text)
except NoSuchElementException:
    Author_name.append('')
    
try:
    volumes_sold=driver.find_elements_by_xpath("//tbody//td[@class='left'][4]")
    for i in volumes_sold:
        Volumes_sold.append(i.text)
except NoSuchElementException:
    Volumes_sold.append('')
    
try:
    publisher=driver.find_elements_by_xpath("//tbody//td[@class='left'][5]")
    for i in publisher:
        Publisher.append(i.text)
except NoSuchElementException:
    Publisher.append('')
    
try:
    genre=driver.find_elements_by_xpath("//tbody//td[@class='last left']")
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('')

# %%
book=pd.DataFrame({})
book['Book_name']=Book_name
book['Author_name']=Author_name
book['Volumes_sold']=Volumes_sold
book['Publisher']=Publisher
book['Genre']=Genre
book
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %% [markdown]
# # Q9.

# %%
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
Name=[]
Year_span=[]
Genre=[]
Run_time=[]
Ratings=[]
Votes=[]

try:
    name=driver.find_elements_by_xpath("//h3[@class='lister-item-header']//a")
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('')
    
try:
    year_span=driver.find_elements_by_xpath("//h3[@class='lister-item-header']//span[2]")
    for i in year_span:
        Year_span.append(i.text)
except NoSuchElementException:
    Year_span.append('')
    
try:
    genre=driver.find_elements_by_xpath("//p[@class='text-muted text-small']//span[5]")
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('')
    
try:
    run_time=driver.find_elements_by_xpath("//p[@class='text-muted text-small']//span[3]")
    for i in run_time:
        Run_time.append(i.text)
except NoSuchElementException:
    Run_time.append('')
    
try:
    votes=driver.find_elements_by_xpath("//p[@class='text-muted text-small'][3]//span[2]")
    for i in votes:
        Votes.append(i.text)
except NoSuchElementException:
    Votes.append('')

# %%
imdb=pd.DataFrame({})
imdb['Name']=Name
imdb['Year_span']=Year_span
imdb['Genre']=Genre
imdb['Run_time']=Run_time
imdb['Votes']=Votes
imdb
# Out:
#                               Name    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time      Votes
# 0    57 min  1,883,743
# 1    51 min    916,993
# ...

# %% [markdown]
# # Q10.

# %%
url='https://archive.ics.uci.edu/ml/index.php'
driver.get(url)

# %%
dataset_btn=driver.find_element_by_xpath("//b[contains(text(),'View ALL Data Sets')]")
dataset_btn.click()

# %%
Name=[]
Data_type=[]
Task=[]
Att_type=[]
Instances=[]
Atr=[]
Yrs=[]

try:
    name=driver.find_elements_by_xpath("//table[@border='1']//tbody//p/b//a")
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('')
    
try:
    data_type=driver.find_elements_by_xpath("//table[@border='1' and @cellpadding='5']/tbody/tr/td[2]/p[@class='normal']")
    for i in data_type:
        Data_type.append(i.text)
except NoSuchElementException:
    Data_type.append('')
    
try:
    task=driver.find_elements_by_xpath("//table[@border='1' and @cellpadding='5']/tbody/tr/td[3]/p[@class='normal']")
    for i in task:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('')
    
try:
    att_type=driver.find_elements_by_xpath("//table[@border='1' and @cellpadding='5']/tbody/tr/td[4]/p[@class='normal']")
    for i in att_type:
        Att_type.append(i.text)
except NoSuchElementException:
    Att_type.append('')
    
try:
    instances=driver.find_elements_by_xpath("//table[@border='1' and @cellpadding='5']/tbody/tr/td[5]/p[@class='normal']")
    for i in instances:
        Instances.append(i.text)
except NoSuchElementException:
    Instances.append('')
    
try:
    atr=driver.find_elements_by_xpath("//table[@border='1' and @cellpadding='5']/tbody/tr/td[6]/p[@class='normal']")
    for i in atr:
        Atr.append(i.text)
except NoSuchElementException:
    Atr.append('')
    
try:
    yrs=driver.find_elements_by_xpath("//table[@border='1' and @cellpadding='5']/tbody/tr/td[7]/p[@class='normal']")
    for i in yrs:
        Yrs.append(i.text)
except NoSuchElementException:
    Yrs.append('')

# %%
repositories = pd.DataFrame({})
repositories['Title']=Name
repositories['Data Types']=Data_type
repositories['Default Task']=Task
repositories['Attribute Types']=Att_type
repositories['Instances']=Instances
repositories['Attributes']=Atr
repositories['Year']=Yrs
repositories
# Out:
#                                 Title     Data Types          Default Task  \
# 0                             Abalone  Multivariate        Classification
# 1                               Adult  Multivariate        Classification
# 2                           Annealing  Multivariate        Classification
# 3        Anonymous Microsoft Web Data                 Recommender-Systems
# 4                          Arrhythmia  Multivariate        Classification
# ..                                ...            ...                   ...
# 583  in-vehicle coupon recommendation  Multivariate        Classification
# 584               Gait Classification  Multivariate        Classification
# 585         Wikipedia Math Essentials   Time-Series            Regression
# 586         Wikipedia Math Essentials   Time-Series            Regression
# 587      Synchronous Machine Data Set  Multivariate            Regression
#
#                  Attribute Types Instances Attributes   Year
# ...
